# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexval259/predicciones_ventas/blob/main/week2_proyecto_prediccion_ventas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PROYECTO SEMANA 2

# %%
import pandas as pd
import numpy as np
import math
filename='/content/drive/MyDrive/Coding_dojo/sales_predictions.csv'
info_data=pd.read_csv(filename)
info_data.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %% [markdown]
# 1) ¿Cuántas filas y columnas?

# %%
info_data.shape
# Out:
# (8523, 12)

# %% [markdown]
# 2) ¿Cuáles son los tipos de datos en cada variable?

# %%
info_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# 3) ¿Hay duplicados? Si es el caso, eliminen algunos duplicados.

# %%
info_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 4) Identifiquen los valores faltantes.

# %%
info_data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# 5) Decidan cómo abordar los valores faltantes y cómo hacerlo. (Esto requiere sus criterios, así que expliquen su elección).

# %%
info_data['Item_Weight'].isna()
info_data.loc[pd.isna(info_data["Item_Weight"]), :].index
# estos datos no pueden ser inventados, ya que el peso del item es muy importante. Se deberia solicitar
# que se entregue la info necesaria
# Out:
# Int64Index([   7,   18,   21,   23,   29,   36,   38,   39,   49,   59,
#             ...
#             8458, 8463, 8469, 8472, 8480, 8485, 8487, 8488, 8490, 8504],
#            dtype='int64', length=1463)

# %%
# Encontrando una relacion entre el item_Weigth y el Item_identifie
missing_items=info_data['Item_Identifier'].value_counts()
print(missing_items)
# Out:
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
filter3=info_data['Item_Identifier'] == 'NCT18'
info_data[filter3].head(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 703            NCT18         14.6          Low Fat         0.059394
# 2451           NCT18         14.6          Low Fat         0.059405
# 7071           NCT18         14.6          Low Fat         0.059741
# 8023           NCT18          NaN          Low Fat         0.059117
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 703   Household  181.7976            OUT035                       2004
# 2451  Household  179.6976            OUT046                       1997
# 7071  Household  179.6976            OUT017                       2007
# 8023  Household  181.5976            OUT027                       1985
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 703        Small               Tier 2  Supermarket Type1          3259.7568
# 2451       Small               Tier 1  Supermarket Type1          3621.9520
# ...

# %%
# crear un dataframe de sproductos que contienen identificador y peso
dfx=info_data[['Item_Identifier','Item_Weight']]
dfx.head()
dfx.duplicated().sum()
dfx=dfx.drop_duplicates()
dfx.dropna(inplace=True)
dfx.shape # (1555, 2), es decir hay 1555 productos
dfx.head()  ### esta es la matriz donde estan los pesos asociadas a un producto
dfx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1555 entries, 0 to 8471
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Item_Identifier  1555 non-null   object
#  1   Item_Weight      1555 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 36.4+ KB

# %%
dfx=dfx.reset_index()  # reseteando el indice
dfx.tail()
for i in range(len(info_data['Item_Identifier'])):
  val=info_data['Item_Identifier'][i]
  val2=info_data['Item_Weight'][i]
  if math.isnan(val2 ):
    #print('flotante',val)
    for j in range(len(dfx['Item_Identifier'])):
      valx=dfx['Item_Identifier'][j]
      valy=dfx['Item_Weight'][j]
      if (valx == val):
        info_data['Item_Weight'][i]=valy
      else:
        pass
  else:
    pass
# Out:
# <ipython-input-10-3e2acc0622d3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   info_data['Item_Weight'][i]=valy

# %%
filter3=info_data['Item_Identifier'] == 'DRE49'
info_data[filter3].head(10) 
# todos los FD13 tienen el mismo peso, porque corresponden a ese producto
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 283            DRE49        20.75          Low Fat         0.021370
# 389            DRE49        20.75               LF         0.021250
# 2092           DRE49        20.75          Low Fat         0.035568
# 2217           DRE49        20.75          Low Fat         0.000000
# 2292           DRE49        20.75          Low Fat         0.021337
# 2923           DRE49        20.75          Low Fat         0.021232
# 4676           DRE49        20.75          Low Fat         0.000000
# 4953           DRE49        20.75          Low Fat         0.021283
# 7874           DRE49        20.75          Low Fat         0.021293
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 283   Soft Drinks  153.0024            OUT017                       2007
# 389   Soft Drinks  150.5024            OUT046                       1997
# ...

# %%
info_data['Item_Weight'].isna()
info_data.loc[pd.isna(info_data["Item_Weight"]), :].index
# Out:
# Int64Index([927, 1922, 4187, 5022], dtype='int64')

# %%
a=info_data['Item_Identifier'][927]
b=info_data['Item_Identifier'][1922]
c=info_data['Item_Identifier'][4187]
d=info_data['Item_Identifier'][5022]
print(a,b,c,d)
# Out:
# FDN52 FDK57 FDE52 FDQ60

# %%
# productos que no el peso no se relaciona al identificador
filterx =((info_data['Item_Identifier']=='FDN52') | 
         (info_data['Item_Identifier']=='FDK57') |
         (info_data['Item_Identifier']=='FDE52') |
         (info_data['Item_Identifier']=='FDQ60'))
info_data[filterx]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 927            FDN52          NaN          Regular         0.130933
# 1922           FDK57          NaN          Low Fat         0.079904
# 4187           FDE52          NaN          Regular         0.029742
# 5022           FDQ60          NaN          Regular         0.191501
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 927   Frozen Foods   86.9198            OUT027                       1985
# 1922   Snack Foods  120.0440            OUT027                       1985
# 4187         Dairy   88.9514            OUT027                       1985
# 5022  Baking Goods  121.2098            OUT019                       1985
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 927       Medium               Tier 3  Supermarket Type3          1569.9564
# 1922      Medium               Tier 3  Supermarket Type3          4434.2280
# ...

# %%
# al ser 4 productos, se podria eliminarlos, sin embargo se perderoa mas informacion,
#info_data['Item_Weight'].fillna(1,inplace=True) si quisieramos reemplazar por un valor de 1#
# al tener solo 4 filas es mejor borrarlas. Recomendacion clase
info_data.dropna(subset=['Item_Weight'],inplace=True)

# %%
filterx =((info_data['Item_Identifier']=='FDN52') | 
         (info_data['Item_Identifier']=='FDK57') |
         (info_data['Item_Identifier']=='FDE52') |
         (info_data['Item_Identifier']=='FDQ60'))
info_data[filterx]
# ya no existen estas filas
info_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8519 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8519 non-null   object
#  1   Item_Weight                8519 non-null   float64
#  2   Item_Fat_Content           8519 non-null   object
#  3   Item_Visibility            8519 non-null   float64
#  4   Item_Type                  8519 non-null   object
#  5   Item_MRP                   8519 non-null   float64
#  6   Outlet_Identifier          8519 non-null   object
#  7   Outlet_Establishment_Year  8519 non-null   int64
#  8   Outlet_Size                6109 non-null   object
#  9   Outlet_Location_Type       8519 non-null   object
#  10  Outlet_Type                8519 non-null   object
#  11  Item_Outlet_Sales          8519 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 865.2+ KB

# %%
info_data=info_data.reset_index()  # reseteando el indice

# %%
info_data.head()
# Out:
#    index Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0      0           FDA15         9.30          Low Fat         0.016047
# 1      1           DRC01         5.92          Regular         0.019278
# 2      2           FDN15        17.50          Low Fat         0.016760
# 3      3           FDX07        19.20          Regular         0.000000
# 4      4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
info_data=info_data.drop(columns=['index'])
info_data.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8514           FDF22        6.865          Low Fat         0.056783
# 8515           FDS36        8.380          Regular         0.046982
# 8516           NCJ29       10.600          Low Fat         0.035186
# 8517           FDN46        7.210          Regular         0.145221
# 8518           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8514         Snack Foods  214.5218            OUT013
# 8515        Baking Goods  108.1570            OUT045
# 8516  Health and Hygiene   85.1224            OUT035
# 8517         Snack Foods  103.1332            OUT018
# 8518         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8514                       1987        High               Tier 3
# 8515                       2002         NaN               Tier 2
# ...

# %%
info_data['Outlet_Size'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 8514    False
# 8515     True
# 8516    False
# 8517    False
# 8518    False
# Name: Outlet_Size, Length: 8519, dtype: bool

# %%
## compracion para saber que outlet no esta asociado a ningun size
missing_outlets=info_data['Outlet_Identifier'].value_counts()
print(missing_outlets)
# Out:
# OUT013    932
# OUT027    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    527
# Name: Outlet_Identifier, dtype: int64

# %%
info_data.groupby(['Outlet_Size','Outlet_Identifier'])['Item_Outlet_Sales'].count()
# Out:
# Outlet_Size  Outlet_Identifier
# High         OUT013               932
# Medium       OUT018               928
#              OUT027               932
#              OUT049               930
# Small        OUT019               527
#              OUT035               930
#              OUT046               930
# Name: Item_Outlet_Sales, dtype: int64

# %%
info_data.groupby(['Outlet_Identifier','Outlet_Type'])['Item_Outlet_Sales'].count()
# Out:
# Outlet_Identifier  Outlet_Type
# OUT010             Grocery Store        555
# OUT013             Supermarket Type1    932
# OUT017             Supermarket Type1    926
# OUT018             Supermarket Type2    928
# OUT019             Grocery Store        527
# OUT027             Supermarket Type3    932
# OUT035             Supermarket Type1    930
# OUT045             Supermarket Type1    929
# OUT046             Supermarket Type1    930
# OUT049             Supermarket Type1    930
# Name: Item_Outlet_Sales, dtype: int64

# %%
info_data.groupby(['Outlet_Type','Outlet_Size'])['Item_Outlet_Sales'].count()
# viendo los resultados de los 3 anteriores groupby, vemos que grocery store es small,
# y deberian haber 527 y 525, por tanto esos 525 deben ser small
# Out:
# Outlet_Type        Outlet_Size
# Grocery Store      Small           527
# Supermarket Type1  High            932
#                    Medium          930
#                    Small          1860
# Supermarket Type2  Medium          928
# Supermarket Type3  Medium          932
# Name: Item_Outlet_Sales, dtype: int64

# %%
info_data.groupby(['Outlet_Size','Outlet_Location_Type'])['Item_Outlet_Sales'].count()
# Out:
# Outlet_Size  Outlet_Location_Type
# High         Tier 3                   932
# Medium       Tier 1                   930
#              Tier 3                  1860
# Small        Tier 1                  1457
#              Tier 2                   930
# Name: Item_Outlet_Sales, dtype: int64

# %%
# aplicando el mismo metodo de inputacion por columana pero reducido.
# crear un dataframe de sproductos que contienen identificador y peso
dfy=info_data[['Outlet_Type','Outlet_Size']]
dfy.head()
dfy.dropna(inplace=True)
#dfy.shape # (6109, 2), 
dfy.head(30)  ### esta es la matriz donde estan los pesos asociadas a un producto
dfy=dfy.drop_duplicates()
dfy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 0 to 23
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Outlet_Type  6 non-null      object
#  1   Outlet_Size  6 non-null      object
# dtypes: object(2)
# memory usage: 144.0+ bytes
# <ipython-input-27-9e7fb92f1a21>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfy.dropna(inplace=True)

# %%
dfy.tail(6)
# Out:
#           Outlet_Type Outlet_Size
# 0   Supermarket Type1      Medium
# 1   Supermarket Type2      Medium
# 4   Supermarket Type1        High
# 7   Supermarket Type3      Medium
# 11  Supermarket Type1       Small
# 23      Grocery Store       Small

# %%
filterNew=dfy['Outlet_Type'] == 'Grocery Store'
dfz=dfy[filterNew]
dfz
# Out:
#       Outlet_Type Outlet_Size
# 23  Grocery Store       Small

# %%
dfz=dfz.reset_index(drop=True)  # reseteando el indice

# %%
dfz.head()
# Out:
#      Outlet_Type Outlet_Size
# 0  Grocery Store       Small

# %%
#dfz.drop(columns=['index'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-3ea589484af0> in <module>
# ----> 1 dfz.drop(columns=['index'],inplace=True)
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
dfz.head()
# Out:
#      Outlet_Type Outlet_Size
# 0  Grocery Store       Small

# %%
val=info_data['Outlet_Type'][1]
val2=info_data['Outlet_Size'][1]

# %%
info_data.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10       19.000          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
for i in range(len(info_data['Outlet_Type'])):
  val=info_data['Outlet_Type'][i]
  val2=info_data['Outlet_Size'][i]
  if val2 == '' or (isinstance(val2, float) and  math.isnan(val2)):
    #print(val)
    for j in range(len(dfz['Outlet_Type'])):
      valx=dfz['Outlet_Type'][j]
      #print(valx)
      valy=dfz['Outlet_Size'][j]
      #print(valy)
      if (str(valx) == str(val)):
        info_data['Outlet_Size'][i]=valy
        #print(i)
      else:
        pass
  else:
    pass
# Out:
# <ipython-input-42-55fab213e798>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   info_data['Outlet_Size'][i]=valy

# %%
##### definicio ojo revisar en el futuro#####
def Upgrade_Item_Identifier_mean(Item_Identifier):
  Item_Identifier_filter  = df['Item_Identifier'] == Item_Identifier
  values_mean = df[Item_Identifier_filter]['Item_Weight'].mean()
  return values_mean

# %%
info_data.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10       19.000          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
info_data.groupby(['Outlet_Location_Type','Outlet_Size'])['Item_Outlet_Sales'].count()
# se creara otra categoria que en outlet_size llame, por verificar
# Out:
# Outlet_Location_Type  Outlet_Size
# Tier 1                Medium          930
#                       Small          1457
# Tier 2                Small           930
# Tier 3                High            932
#                       Medium         1860
#                       Small           555
# Name: Item_Outlet_Sales, dtype: int64

# %%
info_data.groupby(['Outlet_Location_Type','Outlet_Identifier'])['Item_Outlet_Sales'].count()
# se creara otra categoria que en outlet_size llame, por verificar
# Out:
# Outlet_Location_Type  Outlet_Identifier
# Tier 1                OUT019               527
#                       OUT046               930
#                       OUT049               930
# Tier 2                OUT017               926
#                       OUT035               930
#                       OUT045               929
# Tier 3                OUT010               555
#                       OUT013               932
#                       OUT018               928
#                       OUT027               932
# Name: Item_Outlet_Sales, dtype: int64

# %%
dfy1=info_data[['Outlet_Location_Type','Outlet_Size']]
dfy1.head()
dfy1.dropna(inplace=True)
#dfy.shape # (6109, 2), 
dfy1.head(30)  ### esta es la matriz donde estan los pesos asociadas a un producto
dfy1=dfy1.drop_duplicates()
dfy1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Outlet_Location_Type  6 non-null      object
#  1   Outlet_Size           6 non-null      object
# dtypes: object(2)
# memory usage: 144.0+ bytes
# <ipython-input-53-b73237c7c014>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfy1.dropna(inplace=True)

# %%
filterNew2=dfy1['Outlet_Location_Type'] == 'Tier 2'
dfz1=dfy1[filterNew2]
dfz1
# Out:
#    Outlet_Location_Type Outlet_Size
# 19               Tier 2       Small

# %%
dfz1=dfz1.reset_index(drop=True)  # reseteando el indice
dfz1
# Out:
#   Outlet_Location_Type Outlet_Size
# 0               Tier 2       Small

# %%
for i in range(len(info_data['Outlet_Location_Type'])):
  val=info_data['Outlet_Location_Type'][i]
  val2=info_data['Outlet_Size'][i]
  if val2 == '' or (isinstance(val2, float) and  math.isnan(val2)):
    #print(val)
    for j in range(len(dfz1['Outlet_Location_Type'])):
      valx=dfz1['Outlet_Location_Type'][j]
      #print(valx)
      valy=dfz1['Outlet_Size'][j]
      #print(valy)
      if (str(valx) == str(val)):
        info_data['Outlet_Size'][i]=valy
        #print(i)
      else:
        pass
  else:
    pass
# Out:
# <ipython-input-58-e864cb3b28d7>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   info_data['Outlet_Size'][i]=valy

# %%
info_data.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10       19.000          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %% [markdown]
# 6) Confirmen que no hay valores faltantes después de abordarlos.

# %%
info_data.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# 7) Encuentren y arreglen alguna categoría inconsistente de datos (example: fix cat, Cat, and cats so that they are consistent)

# %%
info_data.groupby(['Item_Fat_Content'])['Item_Weight'].count()
# Out:
# Item_Fat_Content
# LF          316
# Low Fat    5088
# Regular    2886
# low fat     112
# reg         117
# Name: Item_Weight, dtype: int64

# %%
info_data['Item_Fat_Content']=info_data['Item_Fat_Content'].replace('LF','Low Fat')
info_data['Item_Fat_Content']=info_data['Item_Fat_Content'].replace('low fat','Low Fat')
info_data['Item_Fat_Content']=info_data['Item_Fat_Content'].replace('reg','Regular')

# %%
info_data.groupby(['Item_Fat_Content'])['Item_Weight'].count()
# Out:
# Item_Fat_Content
# Low Fat    5516
# Regular    3003
# Name: Item_Weight, dtype: int64

# %% [markdown]
# 8) Para cualquier columna numérica, obtengan las estadísticas resumidas para cada uno (mínimo, máximo y media)

# %%
info_data['Item_Weight'].describe().round(2)
# Out:
# count    8519.00
# mean       12.88
# std         4.65
# min         4.56
# 25%         8.78
# 50%        12.65
# 75%        16.85
# max        21.35
# Name: Item_Weight, dtype: float64
